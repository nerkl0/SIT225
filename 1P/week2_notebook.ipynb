# %%
student_name = "Nicole Birch"
student_id = "s225617573"
print("Student name: " + student_name)
print("Student ID: " + student_id)
# Out:
# Student name: Nicole Birch
# Student ID: s225617573

# %%
import random
import matplotlib.pyplot as plt

n_values = 100
y_values = []

# Create data (y_values) randomly between 1 and 100.
for i in range(n_values):
    y_values.append(random.randint(1, 100))

x_values = range(n_values)  # X is sequence of values 0-99
plt.plot(x_values, y_values)
plt.show()

# %%
# Plot 2 variables
# 

n_values = 100
y_values_1 = []
y_values_2 = []

# Create data (y_values) randomly between 1 and 100.
for i in range(n_values):
    y_values_1.append(random.randint(1, 100))
    y_values_2.append(random.randint(1, 100))

x_values = range(n_values)  # X is sequence of values 0-99
plt.plot(x_values, y_values_1)
plt.plot(x_values, y_values_2)  # call plot again draws in the same graph.
plt.show()

# %%
# Activity 1: Create data so that the plot draws an ascending line (y_values increase at any rate).
y_values_3 = []

for i in range(n_values):
    y_values_3.append(i + random.randint(0, 10)) 

x_values = range(n_values)
plt.plot(x_values, y_values_3) 
plt.show()

# %%
# 
# Activity 2: Create data so that the plot draws a 
# descending line (y_values decrease at any rate).
#

# %%
# Activity 3: Create data so that the plot draws a wave. You can consider using Python's math libarary, which has a sin function (detail https://www.w3schools.com/python/ref_math_sin.asp)
import math

y_values_4 = []

for i in range(n_values):
    y_values_4.append(math.sin(i * 0.2))

x_values = range(n_values)
plt.plot(x_values, y_values_4)
plt.show()
